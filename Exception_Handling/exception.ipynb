# %% [markdown]
# # Exception Handling in Python
#
# Exception handling is used to prevent a program from crashing when an unexpected error occurs. It allows the program to handle errors gracefully and continue execution.
#
# ## Basic Syntax
#
# ```python
# try:
#     # Code that may cause an error
# except:
#     # Code executed when an error occurs
# ```
#
# ## Example
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     result = 10 / number
#     print(result)
#
# except ValueError:
#     print("Please enter a valid integer.")
#
# except ZeroDivisionError:
#     print("A number cannot be divided by zero.")
# ```
#
# ## Exception Handling Keywords
#
# ### `try`
#
# Contains the code that may generate an exception.
#
# ### `except`
#
# Handles a specific exception raised inside the `try` block.
#
# ### `else`
#
# Executes only when no exception occurs.
#
# ```python
# try:
#     number = int(input("Enter a number: "))
# except ValueError:
#     print("Invalid input.")
# else:
#     print("You entered:", number)
# ```
#
# ### `finally`
#
# Always executes, whether an exception occurs or not. It is commonly used for cleanup operations such as closing files or database connections.
#
# ```python
# try:
#     file = open("data.txt", "r")
# except FileNotFoundError:
#     print("File not found.")
# finally:
#     print("Operation completed.")
# ```
#
# ### `raise`
#
# Manually generates an exception when a specific condition is invalid.
#
# ```python
# age = -5
#
# if age < 0:
#     raise ValueError("Age cannot be negative.")
# ```
#
# ## Common Python Exceptions
#
# | Exception           | Description                                           |
# | ------------------- | ----------------------------------------------------- |
# | `ValueError`        | A correct data type contains an invalid value         |
# | `TypeError`         | An operation is performed on an unsupported data type |
# | `ZeroDivisionError` | A number is divided by zero                           |
# | `IndexError`        | A list index does not exist                           |
# | `KeyError`          | A dictionary key does not exist                       |
# | `FileNotFoundError` | The requested file cannot be found                    |
# | `NameError`         | A variable has not been defined                       |
#
# ## Best Practices
#
# * Handle specific exceptions instead of using a general `except`.
# * Display clear and meaningful error messages.
# * Keep only error-prone code inside the `try` block.
# * Use `finally` for cleanup operations.
# * Avoid hiding errors without handling them properly.
#
# ## Summary
#
# Exception handling makes Python programs safer and more reliable. The main keywords are:
#
# ```text
# try → Test risky code
# except → Handle an error
# else → Run when no error occurs
# finally → Always run
# raise → Generate an exception manually
# ```

# %%
# Try Except 
try:
    a=b
except:
    print("variable is not defined")
# Out:
# variable is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
except Exception as ex1:
    print(ex1)
    print('Main exception got caught here')
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("enter denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
## try,except,else block
try:
    num=int(input("Enter a number:"))
    result=10/num
except ValueError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
# Out:
# the result is 2.5

# %%
## try,except,else and finally
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("Execution complete.")
# Out:
# The result is 2.5
# Execution complete.

# %%
### File handling and Exception HAndling

try:
    file=open('example1.txt','r')
    content=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("The file does not exists")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file close')
# Out:
# name 'b' is not defined
# file close

# %%
if 'file' in locals():
    print(True)
# Out:
# True

# %%
not file.closed()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 not file.closed()
#
# TypeError: 'bool' object is not callable
