# %% [markdown]
# ````markdown
# # ✨ Python Magic Methods — Concise Guide
#
# ## What are Magic Methods?
#
# Magic Methods, also called **Dunder Methods**, start and end with double underscores.
#
# ```python
# __method__
# ```
#
# Python automatically calls them when we use operators or built-in functions.
#
# ---
#
# # 1. Object Creation
#
# ## `__init__()`
#
# Called automatically when an object is created.
#
# ```python
# class Student:
#     def __init__(self, name):
#         self.name = name
#
# s1 = Student("Hamza")
# print(s1.name)
# ```
#
# ---
#
# ## `__del__()`
#
# Called when an object is destroyed.
#
# ```python
# class Student:
#     def __del__(self):
#         print("Object deleted")
#
# s1 = Student()
# del s1
# ```
#
# ---
#
# # 2. String Representation
#
# ## `__str__()`
#
# Controls `print(object)` output.
#
# ```python
# class Student:
#     def __str__(self):
#         return "Student Object"
#
# s1 = Student()
# print(s1)
# ```
#
# ---
#
# ## `__repr__()`
#
# Returns a developer-friendly representation.
#
# ```python
# class Student:
#     def __repr__(self):
#         return "Student()"
#
# s1 = Student()
# print(repr(s1))
# ```
#
# ---
#
# # 3. Arithmetic Methods
#
# ## `__add__()` — `+`
#
# ```python
# class Number:
#     def __init__(self, value):
#         self.value = value
#
#     def __add__(self, other):
#         return self.value + other.value
#
# print(Number(10) + Number(20))
# ```
#
# ## `__sub__()` — `-`
#
# ```python
# def __sub__(self, other):
#     return self.value - other.value
# ```
#
# ## `__mul__()` — `*`
#
# ```python
# def __mul__(self, other):
#     return self.value * other.value
# ```
#
# ## `__truediv__()` — `/`
#
# ```python
# def __truediv__(self, other):
#     return self.value / other.value
# ```
#
# ## `__floordiv__()` — `//`
#
# ```python
# def __floordiv__(self, other):
#     return self.value // other.value
# ```
#
# ## `__mod__()` — `%`
#
# ```python
# def __mod__(self, other):
#     return self.value % other.value
# ```
#
# ## `__pow__()` — `**`
#
# ```python
# def __pow__(self, other):
#     return self.value ** other.value
# ```
#
# ---
#
# # 4. Comparison Methods
#
# ## `__eq__()` — `==`
#
# ```python
# def __eq__(self, other):
#     return self.value == other.value
# ```
#
# ## `__ne__()` — `!=`
#
# ```python
# def __ne__(self, other):
#     return self.value != other.value
# ```
#
# ## `__lt__()` — `<`
#
# ```python
# def __lt__(self, other):
#     return self.value < other.value
# ```
#
# ## `__le__()` — `<=`
#
# ```python
# def __le__(self, other):
#     return self.value <= other.value
# ```
#
# ## `__gt__()` — `>`
#
# ```python
# def __gt__(self, other):
#     return self.value > other.value
# ```
#
# ## `__ge__()` — `>=`
#
# ```python
# def __ge__(self, other):
#     return self.value >= other.value
# ```
#
# ---
#
# # 5. Container Methods
#
# ## `__len__()`
#
# Controls `len(object)`.
#
# ```python
# class Course:
#     def __init__(self, subjects):
#         self.subjects = subjects
#
#     def __len__(self):
#         return len(self.subjects)
#
# course = Course(["Python", "SQL"])
# print(len(course))
# ```
#
# ---
#
# ## `__getitem__()`
#
# Controls indexing.
#
# ```python
# class Students:
#     def __init__(self):
#         self.names = ["Hamza", "Ali"]
#
#     def __getitem__(self, index):
#         return self.names[index]
#
# students = Students()
# print(students[0])
# ```
#
# ---
#
# ## `__setitem__()`
#
# Updates an item using an index.
#
# ```python
# def __setitem__(self, index, value):
#     self.names[index] = value
# ```
#
# ---
#
# ## `__delitem__()`
#
# Deletes an item using an index.
#
# ```python
# def __delitem__(self, index):
#     del self.names[index]
# ```
#
# ---
#
# ## `__contains__()`
#
# Controls the `in` operator.
#
# ```python
# def __contains__(self, item):
#     return item in self.names
# ```
#
# ---
#
# # 6. Iteration Methods
#
# ## `__iter__()`
#
# Makes an object iterable.
#
# ```python
# class Students:
#     def __init__(self):
#         self.names = ["Hamza", "Ali"]
#
#     def __iter__(self):
#         return iter(self.names)
#
# for name in Students():
#     print(name)
# ```
#
# ---
#
# ## `__next__()`
#
# Returns the next value during iteration.
#
# ```python
# class Counter:
#     def __init__(self):
#         self.value = 1
#
#     def __iter__(self):
#         return self
#
#     def __next__(self):
#         if self.value > 3:
#             raise StopIteration
#
#         current = self.value
#         self.value += 1
#         return current
# ```
#
# ---
#
# # 7. Callable Object
#
# ## `__call__()`
#
# Allows an object to behave like a function.
#
# ```python
# class Greeting:
#     def __call__(self, name):
#         print(f"Hello, {name}")
#
# greet = Greeting()
# greet("Hamza")
# ```
#
# ---
#
# # 8. Conversion Methods
#
# ## `__bool__()`
#
# Controls `bool(object)`.
#
# ```python
# def __bool__(self):
#     return self.value > 0
# ```
#
# ## `__int__()`
#
# Controls `int(object)`.
#
# ```python
# def __int__(self):
#     return int(self.value)
# ```
#
# ## `__float__()`
#
# Controls `float(object)`.
#
# ```python
# def __float__(self):
#     return float(self.value)
# ```
#
# ## `__abs__()`
#
# Controls `abs(object)`.
#
# ```python
# def __abs__(self):
#     return abs(self.value)
# ```
#
# ## `__round__()`
#
# Controls `round(object)`.
#
# ```python
# def __round__(self, digits=0):
#     return round(self.value, digits)
# ```
#
# ---
#
# # 9. Context Manager Methods
#
# ## `__enter__()` and `__exit__()`
#
# Used with the `with` statement.
#
# ```python
# class Manager:
#     def __enter__(self):
#         print("Resource opened")
#         return self
#
#     def __exit__(self, exc_type, exc_value, traceback):
#         print("Resource closed")
#
# with Manager():
#     print("Using resource")
# ```
#
# ---
#
# # 10. Hashing
#
# ## `__hash__()`
#
# Returns the hash value of an object.
#
# ```python
# class Student:
#     def __init__(self, roll_number):
#         self.roll_number = roll_number
#
#     def __hash__(self):
#         return hash(self.roll_number)
# ```
#
# ---
#
# # Quick Reference
#
# | Operation | Magic Method |
# |---|---|
# | Create object | `__init__()` |
# | Print object | `__str__()` |
# | Developer representation | `__repr__()` |
# | Object length | `__len__()` |
# | Addition | `__add__()` |
# | Subtraction | `__sub__()` |
# | Multiplication | `__mul__()` |
# | Division | `__truediv__()` |
# | Equal comparison | `__eq__()` |
# | Less than | `__lt__()` |
# | Indexing | `__getitem__()` |
# | Membership | `__contains__()` |
# | Iteration | `__iter__()` |
# | Next value | `__next__()` |
# | Call object | `__call__()` |
# | Boolean conversion | `__bool__()` |
# | Context manager | `__enter__()`, `__exit__()` |
#
# ---
#
# # Key Point
#
# > Magic Methods allow custom objects to work with Python operators and built-in functions.
#
# For example:
#
# ```python
# obj1 + obj2
# ```
#
# Python internally calls:
#
# ```python
# obj1.__add__(obj2)
# ```
# ````

# %%
## Basics MEthods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def __str__(self):
        return f"{self.name},{self.age} years old"
    
    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"
    
person=Person("KRish",34)
# print(person)
print(repr(person))
# Out:
# Person(name=KRish,age=34)

# %%
# Magic Method
# __str__
class Student:

    def __init__(self, name):
        self.name = name

    def __str__(self): # Automatically Called this when we not use this Magic Method the Output will be :main object at 00x0a0A000
        return f"Student Name: {self.name}"


student1 = Student("Hamza")

print(student1)
# Out:
# Student Name: Hamza

# %%
# __repr__()
class Student:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f"Student(name='{self.name}', age={self.age})"


student1 = Student("Hamza", 22)

print(repr(student1))
# Out:
# Student(name='Hamza', age=22)

# %%
# __len__()
class Course:

    def __init__(self, subjects):
        self.subjects = subjects

    def __len__(self):
        return len(self.subjects)


course = Course(["Python", "SQL", "Machine Learning"])

print(len(course))
# Out:
# 3

# %%
# __add__()
class Number:

    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return self.value + other.value


n1 = Number(10)
n2 = Number(20)

print(n1 + n2)
# Out:
# 30

# %%
# __sub__()
class Number:

    def __init__(self, value):
        self.value = value

    def __sub__(self, other):
        return self.value - other.value


n1 = Number(50)
n2 = Number(20)

print(n1 - n2)
# Out:
# 30

# %%
# __mul__()
class Number:

    def __init__(self, value):
        self.value = value

    def __mul__(self, other):
        return self.value * other.value


n1 = Number(5)
n2 = Number(4)

print(n1 * n2)
# Out:
# 20

# %%
# __truediv__()
class Number:

    def __init__(self, value):
        self.value = value

    def __truediv__(self, other):
        return self.value / other.value


n1 = Number(20)
n2 = Number(5)

print(n1 / n2)
# Out:
# 4.0

# %%
# __floordiv__()
class Number:

    def __init__(self, value):
        self.value = value

    def __floordiv__(self, other):
        return self.value // other.value


n1 = Number(17)
n2 = Number(5)

print(n1 // n2)
# Out:
# 3

# %%
# __Mod__()
class Number:

    def __init__(self, value):
        self.value = value

    def __mod__(self, other):
        return self.value % other.value


n1 = Number(17)
n2 = Number(5)

print(n1 % n2)
# Out:
# 2

# %%
# __pow __()
class Number:

    def __init__(self, value):
        self.value = value

    def __pow__(self, other):
        return self.value ** other.value


n1 = Number(2)
n2 = Number(3)

print(n1 ** n2)
# Out:
# 8

# %%
# __eq__()
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __eq__(self, other):
        return self.marks == other.marks


s1 = Student(80)
s2 = Student(80)

print(s1 == s2)
# Out:
# True

# %%
# __ne__() Not Equal operation
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __ne__(self, other):
        return self.marks != other.marks


s1 = Student(80)
s2 = Student(70)

print(s1 != s2)
# Out:
# True

# %%
# __It__less__()
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __lt__(self, other):
        return self.marks < other.marks


s1 = Student(70)
s2 = Student(80)

print(s1 < s2)
# Out:
# True

# %%
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __le__(self, other):
        return self.marks <= other.marks


s1 = Student(80)
s2 = Student(80)

print(s1 <= s2)
# Out:
# True

# %%
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __gt__(self, other):
        return self.marks > other.marks


s1 = Student(90)
s2 = Student(80)

print(s1 > s2)
# Out:
# True

# %%
class Student:

    def __init__(self, marks):
        self.marks = marks

    def __ge__(self, other):
        return self.marks >= other.marks


s1 = Student(90)
s2 = Student(90)

print(s1 >= s2)
# Out:
# True

# %%
class Students:

    def __init__(self):
        self.names = ["Hamza", "Ali", "Arham"]

    def __getitem__(self, index):
        return self.names[index]


students = Students()

print(students[0])
print(students[1])
# Out:
# Hamza
# Ali

# %%
class Students:

    def __init__(self):
        self.names = ["Hamza", "Ali", "Arham"]

    def __setitem__(self, index, value):
        self.names[index] = value


students = Students()

students[1] = "Ahmed"

print(students.names)
# Out:
# ['Hamza', 'Ahmed', 'Arham']

# %%
class Students:

    def __init__(self):
        self.names = ["Hamza", "Ali", "Arham"]

    def __delitem__(self, index):
        del self.names[index]


students = Students()

del students[1]

print(students.names)
# Out:
# ['Hamza', 'Arham']

# %%
class Students:

    def __init__(self):
        self.names = ["Hamza", "Ali", "Arham"]

    def __contains__(self, name):
        return name in self.names


students = Students()

print("Hamza" in students)
print("Ahmed" in students)
# Out:
# True
# False

# %%
class Students:

    def __init__(self):
        self.names = ["Hamza", "Ali", "Arham"]

    def __iter__(self):
        return iter(self.names)


students = Students()

for name in students:
    print(name)
# Out:
# Hamza
# Ali
# Arham

# %%
class Counter:

    def __init__(self, limit):
        self.current = 1
        self.limit = limit

    def __iter__(self):
        return self

    def __next__(self):
        if self.current > self.limit:
            raise StopIteration

        value = self.current
        self.current += 1
        return value


counter = Counter(3)

for number in counter:
    print(number)
# Out:
# 1
# 2
# 3

# %%
class Greeting:

    def __call__(self, name):
        print(f"Hello, {name}")


greet = Greeting()

greet("Hamza")
# Out:
# Hello, Hamza

# %%
class Greeting:

    def __call__(self, name):
        print(f"Hello, {name}")


greet = Greeting()

greet("Hamza")
# Out:
# Hello, Hamza

# %%
class Number:

    def __init__(self, value):
        self.value = value

    def __abs__(self):
        return abs(self.value)


number = Number(-50)

print(abs(number))
# Out:
# 50

# %%
class Price:

    def __init__(self, amount):
        self.amount = amount

    def __round__(self, digits=0):
        return round(self.amount, digits)


price = Price(99.5678)

print(round(price, 2))
# Out:
# 99.57

# %%
class Price:

    def __init__(self, amount):
        self.amount = amount

    def __int__(self):
        return int(self.amount)


price = Price(99.99)

print(int(price))
# Out:
# 99

# %%
class Price:

    def __init__(self, amount):
        self.amount = amount

    def __float__(self):
        return float(self.amount)


price = Price("99.99")

print(float(price))
# Out:
# 99.99

# %%
class FileManager:

    def __enter__(self):
        print("Resource opened")
        return self

    def __exit__(self, exception_type, exception_value, traceback):
        print("Resource closed")


with FileManager() as manager:
    print("Using resource")
# Out:
# Resource opened
# Using resource
# Resource closed

# %%
class Student:

    def __init__(self, registration_number):
        self.registration_number = registration_number

    def __hash__(self):
        return hash(self.registration_number)


student = Student("FA22-BCS-001")

print(hash(student))
# Out:
# 158939401551868718

# %%
class Student:

    def __init__(self, name):
        self.name = name
        print("Object created")

    def __del__(self):
        print("Object deleted")


student = Student("Hamza")

del student
# Out:
# Object created
# Object deleted
