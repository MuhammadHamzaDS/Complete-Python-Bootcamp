# %%
# Single Inheritance
# Parent Class 
class Car:
    def __init__(self,windows,doors,enginetype):
        self.window=windows
        self.doors=doors
        self.enginetype=enginetype

    def drive(self):
        print(f"It is an {self.enginetype} car")

car1=Car(4,4,"Petrol")
car1.drive()
# Out:
# It is an Petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving
    def selfdrive(self):
        print(f"{self.is_selfdriving} Your Car is Self Driving Car")
    def detail(self):
        print(f"Your Car has {self.window} windows.{self.doors} Doors and is {self.enginetype} Car")

car2=Tesla(4,5,"Electric",True)
car2.selfdrive()
car2.detail()
# Out:
# True Your Car is Self Driving Car
# Your Car has 4 windows.5 Doors and is Electric Car

# %%
# using Mulitple Inheritance
class Animal:
    def __init__(self,name):
        self.name=name

class Pet:
    def __init__(self,owner):
        self.owner=owner


class Dog(Animal,Pet):
    def __init__(self,owner,name):
      Animal.__init__(self,name)
      Pet.__init__(self,owner)

    def speak(self):
        print(f"Your {self.name},Whose Owner Name is {self.owner} is barking")

dog1=Dog("Luffy","Hamza")
dog1.speak()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 19
#      16     def speak(self):
#      17         print(f"Your {self.name},Whose Owner Name is {self.owner} is barking")
# ---> 19 dog1=Dog("Luffy","Hamza")
#      20 dog1.speak()
#
# Cell In[18], line 13, in Dog.__init__(self, owner, name)
#      12 def __init__(self,owner,name):
# ---> 13   Animal.__init__(self,name)
#      14   Pet.__init__(self,owner)
#
# TypeError: object.__init__() takes exactly one argument (the instance to initialize)
