# %%
def hamza(**hamza):
    print(hamza)




hamza(name ="hamza",agr="20",city="Sahiwal")
# Out:
# {'name': 'hamza', 'agr': '20', 'city': 'Sahiwal'}

# %%
# Map Function with Multiple Iterables
numbers1=[1,2,3,4]
numbers2=[3,4,5,6]
added_numbers=list(map(lambda x,y:x+y,numbers1,numbers2 ))
