# %% [markdown]
# # Variable-Length Arguments
#
# ## Definition
#
# **Variable-length arguments** allow a function to accept a **variable (unknown) number of arguments** at runtime, making the function more flexible and reusable.
#
# ### Types
#
# - **`*args`** → Accepts multiple **positional arguments** and stores them in a **tuple**.
# - **`**kwargs`** → Accepts multiple **keyword arguments** and stores them in a **dictionary**.
#
# ## Interview Definition
#
# > **Variable-length arguments allow a function to accept an unspecified number of arguments. In Python, `*args` collects positional arguments into a tuple, while `**kwargs` collects keyword arguments into a dictionary.**

# %%
# *args
def add(*numbers):
    return sum(numbers)

print(add(10, 20))
print(add(10, 20, 30))
# Out:
# 30
# 60

# %%
# *kwargs
def student(**kwargs):
    print(kwargs)

student(name="Hamza", age=22, course="Python")
def skills(**kwargs):
    for key,values in kwargs.items():
        print(f"{key}:Value")

skills(name="Khan",age=33,city="sahiwal")
# Out:
# {'name': 'Hamza', 'age': 22, 'course': 'Python'}
# name:Value
# age:Value
# city:Value

# %%
# Map Function with Multiple Iterables
numbers1=[1,2,3,4]
numbers2=[3,4,5,6]
added_numbers=list(map(lambda x,y:x+y,numbers1,numbers2 ))
print(added_numbers)

# %%
# Map with Single Iterbale

def sqaure(a):
    return a*a
nums=[2,3,4,5,6,7]
sqaure_num=list(map(sqaure,nums))
print(sqaure_num)
# Out:
# [4, 9, 16, 25, 36, 49]

# %%
# map() Function to Convert String to integers
numbers=['1','2','3','4','5']
to_integer=list(map(int,numbers))
print(to_integer)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Conert Lowercase to Uppercase
words=['apple','banana','grapes']
uppercase=list(map(str.upper,words))
print(uppercase)
# Out:
# ['APPLE', 'BANANA', 'GRAPES']

# %%
# Map( with Disctionaries)
def get_name(person):
    return person['name']
people=[
    {'name':'Hamza','age':22},
    {'name':'Arham','age':22}
]
list(map(get_name,people))
# Out:
# ['Hamza', 'Arham']

# %%
# Filter()
def even(num):
    if num%2==0:
        return True

# %%
All=[1,2,4,5,6,7,7,8,9,5]
# list(filter(even,All))
even_numbers=list(filter(lambda x:x%2==0,All))
print(even_numbers)
# Out:
# [2, 4, 6, 8]

# %%
def temperature(cel):
    f=9/5*(cel)+32
    return f
fran=int(input("enter celcius"))  #input() always return string that's why we use type casting
input=temperature(fran)
print(input)
# Out:
# 152.60000000000002
