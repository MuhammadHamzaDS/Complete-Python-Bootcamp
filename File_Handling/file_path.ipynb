# %%
# Finding Current Directory
import os
cwd= os.getcwd()
print(f"Current Working Directroy is {cwd}")
# Out:
# Current Working Directroy is d:\Complete_Python_Bootcamp\Complete-Python-Bootcamp\File_Handling

# %%
# Making new Dir 
new_directory='package'
os.mkdir(new_directory)
print(f"New Directory {new_directory} is created")
# Out:
# New Directory package is created

# %%
# Listing  dir in the current folder
items= os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'file_operations.ipynb', 'file_path.ipynb', 'package']

# %%
# Joining
dir_name='folder'
file_name='file.txt'
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name='folder'
file_name='file.txt'
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\Complete_Python_Bootcamp\Complete-Python-Bootcamp\File_Handling\folder\file.txt

# %%
# Find file in the path 
path='package'
if os.path.isfile(path):
    print(f"The path {path} is a File")
elif os.path.isdir(path):
    print(f"The path {path} is a  Directory")
else:
    print(f"The Path {path} is  neither a File nor a Directory")
# Out:
# The path package is a  Directory
