# %%
import array
arr=array.array('i',[1,2,3,4,5,6])   # i means array is an signed integer(data_type,Typecode)
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5, 6])

# %%
# play with your friends
import random
print(random.randint(1,45))
print(random.choice(['bunk the class','take the class','Go to Snooker']))
how_many_classes=random.randint(1,6)
decsiion=random.choice(['Take the class','Bunk The Class','Play Snooker'])
print(f"You have to  attend {how_many_classes}  in a week and you may {decsiion}")
# Out:
# 10
# bunk the class
# You have to  attend 1  in a week and you may Bunk The Class

# %%
import os 
os.getcwd()
# Out:
# 'd:\\Complete_Python_Bootcamp\\Complete-Python-Bootcamp\\4-Modules'

# %%
os.mkdir('text_dir')

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
# Data Serialization
# From dic to Json and from json to Dic 
import json
data={'name':'Hamza','age':23}
print(type(data))
json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# {"name": "Hamza", "age": 23}
# <class 'str'>
# {'name': 'Hamza', 'age': 23}
# <class 'dict'>

# %%
with open('example.txt','w') as file:
    file.write("This is about File handling in Python\n")
    file.writelines("this is a multiple line function")
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# This is about File handling in Python
# this is a multiple line function

# %%
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Krish',32])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-07-19 02:56:58.858827
# 2026-07-18 02:56:58.858827

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1784455022.3019722
# 1784455024.3031473

# %%
#Regualr Expression

import re
pattern=r'\d+'
Text='There is 123 bananas In the Bucket'
match=re.search(pattern,Text)
print(match.group())
# Out:
# 123
